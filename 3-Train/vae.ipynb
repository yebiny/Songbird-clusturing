# %%
from trainVAE import *

# %%
save_path='train_result/train_0729_2/'
x_train = np.load('../data/w58y67/prepro_0729/x_train.npy')
x_test = np.load('../data/w58y67/prepro_0729/x_test.npy')

# %%
vae = TrainVAE(x_train, 10, save_path)
vae.vae.summary()
# Out:
# Model: "vae"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_9 (InputLayer)         [(None, 128, 64, 1)]      0
# _________________________________________________________________
# encoder (Model)              [(None, 10), (None, 10),  361396
# _________________________________________________________________
# decoder (Model)              (None, 128, 64, 1)        359809
# ...
# Total params: 721,205
# Trainable params: 721,205
# Non-trainable params: 0
# _________________________________________________________________

# %%
vae.train(300, 256)
# Out:
# * 0 * loss: 5260.084473,  best_loss: 5260.084473, l_rate: 0.001000, lr_count: 0
# * 1 * loss: 5207.940918,  best_loss: 5207.940918, l_rate: 0.001000, lr_count: 0
# * 2 * loss: 5205.229492,  best_loss: 5205.229492, l_rate: 0.001000, lr_count: 0
# * 3 * loss: 5202.970703,  best_loss: 5202.970703, l_rate: 0.001000, lr_count: 0
# * 4 * loss: 5201.220703,  best_loss: 5201.220703, l_rate: 0.001000, lr_count: 0
# * 5 * loss: 5199.850098,  best_loss: 5199.850098, l_rate: 0.001000, lr_count: 0
# * 6 * loss: 5198.702637,  best_loss: 5198.702637, l_rate: 0.001000, lr_count: 0
# * 7 * loss: 5197.430176,  best_loss: 5197.430176, l_rate: 0.001000, lr_count: 0
# * 8 * loss: 5196.441895,  best_loss: 5196.441895, l_rate: 0.001000, lr_count: 0
# * 9 * loss: 5195.555664,  best_loss: 5195.555664, l_rate: 0.001000, lr_count: 0
# * 10 * loss: 5194.708008,  best_loss: 5194.708008, l_rate: 0.001000, lr_count: 0
# * 11 * loss: 5194.273926,  best_loss: 5194.273926, l_rate: 0.001000, lr_count: 0
# ...

# %%
rec = vae.vae.predict(x_train)
lat =  vae.encoder.predict(x_train)[2]

# %%
rec_test = vae.vae.predict(x_test)
lat_test =  vae.encoder.predict(x_test)[2]

# %%
np.save(save_path+'/rec', rec)
np.save(save_path+'/lat', lat)
np.save(save_path+'/rec_test', rec_test)
np.save(save_path+'/lat_test', lat_test)
rec.shape, lat.shape, rec_test.shape, lat_test.shape
# Out:
# ((49414, 128, 64, 1), (49414, 10), (5491, 128, 64, 1), (5491, 10))

# %%
from basic import *

idx = 10

figure = plt.figure()
plt.subplot(1,2,1)
plt.imshow(x_train[idx].reshape(128,64))
plt.subplot(1,2,2)
plt.imshow(rec[idx].reshape(128,64))
plt.show()
