# %%
from trainVAE import *

# %%
data_path='../0-Data/w58y67/prepro_0729/'
save_path='../5-Results/train_0729/lat_100/'

# %%
vae = TrainVAE(100, data_path, save_path)
vae.vae.summary()
# Out:
# Model: "vae"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         [(None, 128, 64, 1)]      0
# _________________________________________________________________
# encoder (Model)              [(None, 100), (None, 100) 407656
# _________________________________________________________________
# decoder (Model)              (None, 128, 64, 1)        382849
# ...
# Total params: 790,505
# Trainable params: 790,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
vae.train(300, 256)
# Out:
# * 0 * loss: 5363.816895,  best_loss: 5363.816895, l_rate: 0.001000, lr_count: 0
# * 1 * loss: 5254.833008,  best_loss: 5254.833008, l_rate: 0.001000, lr_count: 0
# * 2 * loss: 5221.312012,  best_loss: 5221.312012, l_rate: 0.001000, lr_count: 0
# * 3 * loss: 5212.027832,  best_loss: 5212.027832, l_rate: 0.001000, lr_count: 0
# * 4 * loss: 5205.342285,  best_loss: 5205.342285, l_rate: 0.001000, lr_count: 0
# * 5 * loss: 5201.384766,  best_loss: 5201.384766, l_rate: 0.001000, lr_count: 0
# * 6 * loss: 5199.049805,  best_loss: 5199.049805, l_rate: 0.001000, lr_count: 0
# * 7 * loss: 5196.361328,  best_loss: 5196.361328, l_rate: 0.001000, lr_count: 0
# * 8 * loss: 5195.139648,  best_loss: 5195.139648, l_rate: 0.001000, lr_count: 0
# * 9 * loss: 5193.715332,  best_loss: 5193.715332, l_rate: 0.001000, lr_count: 0
# * 10 * loss: 5192.770508,  best_loss: 5192.770508, l_rate: 0.001000, lr_count: 0
# * 11 * loss: 5191.537109,  best_loss: 5191.537109, l_rate: 0.001000, lr_count: 0
# ...

# %%
vae.plot_recimg(2)

# %%
rec, lat, rec_test, lat_test = vae.save_latent_val(1)
# Out:
# (49414, 128, 64, 1) (49414, 2) (5491, 128, 64, 1) (5491, 2)
