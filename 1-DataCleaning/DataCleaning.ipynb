# %%
from dataCleaning import *

# %%
data_path = '../0-Data/org/'
DC = DataClean(data_path)

# %%
wav_list = DC.wav_list
print('* Total wav files : ', len(wav_list))
# Out:
# * Total wav files :  23

# %%
DC.check_wav_img(7)

# %%
syllable_list = DC.get_syllable_list(wav_list)
print('* Output shape: ', syllable_list.shape)
# Out:
# * Finish Idx 0 wav file :  w58y67_20200416_082440_615
# * Finish Idx 10 wav file :  w58y67_20200419_104314_638
# * Finish Idx 20 wav file :  w58y67_20200503_174608_047
# * Output shape:  (508, 3)

# %%
hist_syllable_lenth(syllable_list[:,2], [0, 10000])

# %%
Ab=Abnormal(syllable_list, wav_list)

# %%
overlen_idx = Ab.get_overlen(10000)
overlen_idx=np.sort(list(set(overlen_idx)))
overlen_idx
# Out:
# array([], dtype=float64)

# %%
Ab.save_abnormal_img(overlen_idx, save_path)

# %%
#abnormal_idx=[1895, 1896, 2768, 2889, 2890, 2891 ]
#abnormal_idx=[78,95,317,692,714,915]
abnormal_idx=[]
syllable_selected = Ab.remove_abnormal(abnormal_idx, 10000)
syllable_selected.shape
# Out:
# (508, 3)

# %%
hist_syllable_lenth(syllable_selected[:, 2])

# %%
def save_dataset(save_path):
    if_not_make(save_path)
    if_not_make(save_path+'/pre')
    np.save('%s/pre/wav_list'%save_path, wav_list)
    np.save('%s/pre/sylla_list'%save_path, syllable_selected)
    
    print(len(wav_list), syllable_selected.shape)

# %%
save_path = '../5-Results/bengal/0914'
save_dataset(save_path)
# Out:
# 23 (508, 3)
