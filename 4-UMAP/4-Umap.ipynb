# %%
from umapAnalysis import *

# %%
datadir = '../0-Data/w58y67/prepro_0729/'
resdir2='../5-Results/train_0729/lat_2/'
resdir10='../5-Results/train_0729/lat_10/'

# %%
ua10 = UmapAnalysis(datadir, resdir10)
ua2 = UmapAnalysis(datadir, resdir2)

# %%
umaped10 = ua10.umap_embedding(ua10.xlat, 1)
umaped2 = ua2.umap_embedding(ua2.xlat, 1)
# Out:
# (49414, 2)
# (49414, 2)

# %%
xexpand=ua10.xtrain.reshape(len(ua10.xtrain), 128*64)
xexpand.shape
# Out:
# (49414, 8192)

# %%
umaped = ua10.umap_embedding(xexpand)
# Out:
# (49414, 2)

# %%
np.save('../5-Results/train_0729/umap_expand', umaped)

# %%
labels10= ua10.kmeans_clustering(umaped10, 12, 1)
labels2= ua2.kmeans_clustering(umaped2, 12, 1)
# Out:
# (49414,)
# (49414,)

# %%
ua10.plot_projection(umaped, labels10)

# %%
ua10.plot_projection(umaped10, labels10)

# %%
ua2.plot_projection(ua2.xlat, labels10)
