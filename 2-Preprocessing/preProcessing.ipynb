# %%
from preProcessing import *

# %%
path = '../5-Results/bengal/0914/pre'
df = PreProcess(path)
sylla_list=df.sylla_list
wav_list = df.wav_list
sylla_list.shape, wav_list.shape
# Out:
# ((508, 3), (23,))

# %%
df.draw_wav(0)

# %%
df.draw_syllable(5)
# Out:
# 0.43 2.0

# %%
data = []
for idx in range(len(sylla_list)):
    arr = df.get_img_arr(idx, 64, 128)
    data.append(arr)
    if idx%100==0:
        print(idx)
data = np.array(data)
data.shape
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# (508, 128, 64)

# %%
data = data/255
np.save('%s/data'%path, data)
np.save('%s/x_train'%path, data.reshape(len(data), 128, 64, 1))
np.save('%s/x_test'%path, data.reshape(len(data), 128, 64, 1))
wav_list.shape, sylla_list.shape, data.shape
# Out:
# ((23,), (508, 3), (508, 128, 64))

# %%
data.shape
# Out:
# (508, 128, 64)

# %%
np.multiply(data.shape[1:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-2c6a333548a1> in <module>
# ----> 1 np.multiply(data.shape[1:])
#
# ValueError: invalid number of arguments

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-6983a1a7f36c> in <module>
# ----> 1 import models
#       2 def vae_loss(x, rec_x):
#       3
#       4     z_mean, z_log_var, z = encoder(x)
#       5     rec_x = decoder(z)
#
# ModuleNotFoundError: No module named 'models'
